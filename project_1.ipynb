# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
# Прочитаем данные из CSV-файла
df = pd.read_csv('data/hh_vacancies.csv', sep=';')

# Определяем размерность таблицы.
shape = df.shape

# Выводим размерность таблицы.
print(shape)
# Out:
# (44744, 12)

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
# Выводим первые и последние 5 строк таблицы
display(df)
# Out:
#                                        Пол, возраст           ЗП  \
# 0        Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1         Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2      Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3          Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4         Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
# ...                                             ...          ...
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 0                                Системный администратор
# 1                                   Технический писатель
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
# Выводим общую статистику DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
# Выводим общую информацию о DataFrame
display(df.describe(include='all'))
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
# Создаем признак "Образование"
def get_education_level(row):
    words = row.split()
    if len(words) < 2:
        return None  # Обработка случаев, когда меньше 2 слов
    education = ' '.join(words[:2]).lower()
    if 'неоконченное высшее' in education:
        return 'неоконченное высшее'
    elif 'высшее' in education:
        return 'высшее'
    elif 'среднее специальное' in education:
        return 'среднее специальное'
    elif 'среднее образование' in education:
        return 'среднее'
    else:
        return None # Для случаев, которые не соответствуют ни одному условию

df['Образование'] = df['Образование и ВУЗ'].apply(get_education_level)

# Проверяем уникальные значения
print(df['Образование'].unique())

# Удаляем исходный признак
df = df.drop('Образование и ВУЗ', axis=1)

# Смотрим на обновлённую таблицу
display(df.head())

##############################

# Подсчитываем соискателей со средним образованием
average_education_count = df[df['Образование'] == 'среднее'].shape[0]

# Выводим результат
print(f"Количество соискателей имеют среднее образование: {average_education_count}")
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# Создаем признаков "Пол" и "Возраст"
def extract_gender_age(row):
    parts = row.split(', ')
    gender = parts[0]
    age = int(parts[1].split()[0])
    return pd.Series({'Пол': gender, 'Возраст': age})  # Возвращаем pd.Series

df[['Пол', 'Возраст']] = df['Пол, возраст'].apply(extract_gender_age)

# Преобразовываем пол к "М" и "Ж"
df['Пол'] = df['Пол'].apply(lambda x: 'М' if 'Мужчина' in x else 'Ж')

# Удаляем исходый признак "Пол, возраст"
df = df.drop('Пол, возраст', axis=1)

# Выводим первые 5 строк DataFrame для проверки
display(df.head())

##############################

# Расчитываем процент женских резюме
female_percentage = round((df['Пол'].value_counts(normalize=True)['Ж']) * 100, 2)

# Расчитываем среднего возраста
average_age = round(df['Возраст'].mean(), 1)

# Выводим результатов
print(f"Процент женских резюме: {female_percentage}%")
print(f"Средний возраст соискателей: {average_age}")
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
# Преобразовываем опыт работы в месяцы
def get_experience(arg):
    
    if arg is np.nan or arg == 'Не указано':
        return None
    
    if "нет опыта работы" in arg.lower() or "без опыта работы" in arg.lower():
        return 0
    
    year_words=['год', 'года', 'лет']
    month_words=['месяц', 'месяца', 'месяцев']
    arg_splitted = arg.split(' ')[:7]
    years = 0
    months = 0
    
    for index, item in enumerate (arg_splitted):
        
        if item in year_words:
            years = int(arg_splitted[index-1])
            
        if item in month_words:
            months = int(arg_splitted[index-1])
            
    return int(years*12 + months)

df['Опыт работы (месяц)'] = df['Опыт работы'].apply(get_experience)

# Удаляем исходный столбец "Опыт работы"
df = df.drop('Опыт работы', axis=1)

# Вывод первых 5 строк DataFrame для проверки
display(df.head())

##############################

# Расчитываем медианный опыт работы
median_experience = df['Опыт работы (месяц)'].median()

# Выводим результата
print(f"Медианный опыт работы (в месяцах): {median_experience}")
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
# Преобразование признака "Город"
def get_city(arg):
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород',
                      'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 
                      'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград'
                     ]
    city = arg.split(' , ')[0]
    if (city == 'Москва') or (city == 'Санкт-Петербург'):
        return city
    elif city in million_cities:
        return 'город миллионник'
    else:
        return 'другие'

# Преобразование признака "Готовность к переезду"
def get_ready_to_move(arg):
    if ('не готов к переезду' in arg) or ('не готова к переезду' in arg):
        return False
    elif 'хочу' in arg:
        return True
    else:
        return True

# Преобразование признака "Готовность к командировкам"  
def get_ready_for_bisiness_trips(arg):
    if ('командировка' in arg):
        if ('не готов к командировкам' in arg) or('не готова к командировкам' in arg):
            return False
        else: 
            
            return True
    else:
        return False

# Вносим изменения в таблицу   
df['Город'] = df['Город, переезд, командировки'].apply(get_city)
df['Готовность к переезду'] = df['Город, переезд, командировки'].apply(get_ready_to_move)
df['Готовность к командировкам'] = df['Город, переезд, командировки'].apply(get_ready_for_bisiness_trips)

# Удаляем исходный столбец "Город, переезд, командировки"
df = df.drop('Город, переезд, командировки', axis=1)

# Выводим первые 5 строк DataFrame для проверки
display(df.head())

##############################

# Расчитываем процент
spb_percentage = (round(df['Город'].value_counts(normalize=True)['Санкт-Петербург'] * 100)) 
location_trip_percentage = (round(df[df['Готовность к переезду'] & df['Готовность к командировкам']].shape[0] / df.shape[0] *100))

# Выводим результаты
print(f"Процент соискателей, живущих в Санкт-Петербурге: {spb_percentage}%")
print(f"Процент соискателей, готовых и к переездам, и к командировкам: {location_trip_percentage}%")
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# 2                                        полный день
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# One-Hot Encoding мигалки для признаков "Занятость" и "График"
employment_types = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
schedule_types = ['полный день', 'сменный график', 'гибкий график', 'удалённая работа', 'вахтовый метод']

for employment in employment_types:
    df[employment] = df['Занятость'].apply(lambda x: employment in x)

for schedule in schedule_types:
    df[schedule] = df['График'].apply(lambda x: schedule in x)

# Удаляем исходные столбцы "Занятость" и "График"
df = df.drop('Занятость', axis=1)
df = df.drop('График', axis=1)

# Выводим первые 5 строк DataFrame для проверки
display(df.head())

##############################

# Расчитываем количества людей, ищущих проектную работу и волонтерство
project_work_and_volunteering_count = len(df[(df['проектная работа'] == True) & (df['волонтерство'] == True)])

# Расчиываем количества людей, желающих работать вахтовым методом и с гибким графиком
rotational_and_flexible_schedule_count = len(df[(df['вахтовый метод'] == True) & (df['гибкий график'] == True)])

# Вывод результатов
print(f"Количество людей, ищущих проектную работу и волонтерство: {project_work_and_volunteering_count}")
print(f"Количество людей, желающих работать вахтовым методом и с гибким графиком: {rotational_and_flexible_schedule_count}")
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# Загружаем данные о курсах валют из CSV-файла
rates = pd.read_csv('data/ExchangeRates.csv') 

# Преобразовываем даты
rates['date'] = pd.to_datetime(rates['date'], dayfirst=True).dt.date
df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме'], dayfirst=True).dt.date

# Функции для извлечения суммы и валюты
def get_salary_num(arg):
    salary = float(arg.split(' ')[0])
    return salary

# Функция для извлечения валюты из строки
def get_salary_currency(arg):
    currency_dict = {
        'USD': 'USD', 'KZT': 'KZT',
        'грн': 'UAH', 'белруб': 'BYN',
        'EUR': 'EUR', 'KGS': 'KGS',
        'сум': 'UZS', 'AZN': 'AZN'
    }
    curr = arg.split(' ')[1].replace('.', '')
    if curr == 'руб':
        return 'RUB'
    else:
        return currency_dict[curr]

# Создаем временные столбцы
df['ЗП (tmp)'] = df['ЗП'].apply(get_salary_num)
df['Курс (tmp)'] = df['ЗП'].apply(get_salary_currency)

# Объединеням таблицы
merged = df.merge(
    rates,
    left_on=['Курс (tmp)', 'Обновление резюме'],
    right_on=['currency', 'date',],
    how='left'
)

# Заполняем пропуски и расчитываем "ЗП (руб)"
merged['close'] = merged['close'].fillna(1)
merged['proportion'] = merged['proportion'].fillna(1)
df['ЗП (руб)'] = merged['close'] * merged['ЗП (tmp)'] / merged['proportion']

# Удаляем лишние столбцы
df = df.drop(['ЗП', 'ЗП (tmp)', 'Курс (tmp)'], axis=1)

display(df.head())

###########################

# Выводим медианное значение заработной платы в рублях (в тысячах), округленное до целого числа
print(round(df['ЗП (руб)'].median()/1000))
# Out:
# C:\Users\zebra\AppData\Local\Temp\ipykernel_6408\239963156.py:5: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор        2019-04-16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  object
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44574 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
#  11  Готовность к командировкам       44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
import plotly.tools as tls
import plotly.offline as py

# Строим гистограмму и коробчатую диаграмму для "Возраст"
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Гистограмма
sns.histplot(data=df, x='Возраст', bins=30, ax=axes[0])
axes[0].set_title('Распределение возраста')
axes[0].set_xlabel('Возраст')
axes[0].set_ylabel('Частота')

# Коробчатая диаграмма
sns.boxplot(data=df, x='Возраст', ax=axes[1])
axes[1].set_title('Коробчатая диаграмма возраста')
axes[1].set_xlabel('Возраст')

plt.show()

# Описание распределения
mode = df['Возраст'].mode()[0]
min_age = df['Возраст'].min()
max_age = df['Возраст'].max()
most_common_age_range = "25-40"  # Приблизительный интервал по визуальному анализу
anomalies = df[df['Возраст'] > 60]['Возраст'].unique().tolist() # Возраст больше 60

print(f"Мода распределения: {mode}")
print(f"Минимальный возраст: {min_age}")
print(f"Максимальный возраст: {max_age}")
print(f"Примерный интервал большинства соискателей: {most_common_age_range}")
print(f"Аномалии (возраст > 60): {anomalies}")


# Преобразуем график Matplotlib в объект Plotly
# fig.write_html("data/age.html")
# Out:
# Мода распределения: 30
# Минимальный возраст: 14
# Максимальный возраст: 100
# Примерный интервал большинства соискателей: 25-40
# Аномалии (возраст > 60): [62, 72, 61, 71, 63, 64, 68, 73, 66, 65, 77, 67, 69, 76, 70, 100]

# %% [markdown]
# Сохранение графика plotly
#
# Чтобы сохранить интерактивный график, построенный в библиотеке Plotly, чаще всего используется метод фигуры fig.write_html('path/to/file.html'), который сохраняет график в формате HTML, после чего вы можете вставлять его на свой сайт, в веб-приложение или просто делиться им с коллегами.
#
# Сохраним график трёхмерной диаграммы рассеяния:
#
# fig.write_html("plotly/scatter_3d.html")
# В результате в папке plotly (которую необходимо создать заранее) у вас появится файл с графиком.
#
# ✍ В библиотеке Plotly насчитываются десятки различных графиков и сотни возможных настроек к ним. В этом юните мы лишь прикоснулись к этой сокровищнице, погружаться ли в неё с головой — решать вам.
#
# Принципы построения других базовых типов графиков вы можете найти здесь, а все способы визуализации статистических показателей и зависимостей перечислены здесь.
#
# А теперь предлагаем вам самим попрактиковаться в использовании библиотеки Plotly ↓

# %% [markdown]
# ### Выводы:
#
# + Распредление имеет правостороннюю ассиметрию, что говорит о том, что основная целевая аудитория, ищущая работу — это специалисты в возрасте от 25 до 40 лет;
#
# + Наиболее встречающийся возраст (мода) и центр распределения (медиана) составляет приблизительно 30 лет;
#
# + Минимальный возраст - 14 лет, максимальный - 100 лет;
#
# + Значения возраста выше 60 лет можно рассматривать как потенциальные аномалии (выбросы) так как находятся за пределами рисок на коробчатой диаграмме, что может говорить о желании людей в возрасте снова выйти на рынок труда либо о желании сменить профессиональную деятельность.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Строим гистограмму и коробчатую диаграмму для "Опыт работы (месяц)"
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Гистограмма
sns.histplot(data=df, x='Опыт работы (месяц)', bins=50, ax=axes[0])
axes[0].set_title('Распределение опыта работы (месяц)')
axes[0].set_xlabel('Опыт работы (месяц)')
axes[0].set_ylabel('Частота')

# Коробчатая диаграмма
sns.boxplot(data=df, x='Опыт работы (месяц)', ax=axes[1])
axes[1].set_title('Коробчатая диаграмма опыта работы (месяц)')
axes[1].set_xlabel('Опыт работы (месяц)')

plt.show()

# Описание распределения
mode = df['Опыт работы (месяц)'].mode()[0]
min_experience = df['Опыт работы (месяц)'].min()
max_experience = df['Опыт работы (месяц)'].max()
most_common_experience_range = "0-150"  # Приблизительный интервал по визуальному анализу
anomalies = df[df['Опыт работы (месяц)'] > 300]['Опыт работы (месяц)'].unique().tolist() # Опыт > 300

print(f"Мода распределения оптыа работы: {mode}")
print(f"Минимальный опыт работы: {min_experience}")
print(f"Максимальный опыт работы: {max_experience}")
print(f"Примерный интервал большинства соискателей: {most_common_experience_range}")
print(f"Аномалии (опыт > 300): {anomalies}")
# Out:
# Мода распределения оптыа работы: 81.0
# Минимальный опыт работы: 0.0
# Максимальный опыт работы: 1188.0
# Примерный интервал большинства соискателей: 0-150
# ...

# %% [markdown]
# ### Выводы:
#
# + Распределение опыта работы (в месяцах), отображенное на гистограмме и коробчатой диаграмме, имеет правостороннюю асимметрию. Это означает, что хвост распределения простирается вправо, что указывает на наличие соискателей с большим опытом работы, чем большинство;
#
# + Наиболее часто встречающийся опыт работы (мода) составляет 81 месяц (6 лет и 9 месяцев);
#
# + Медиана Центр распределения (медиана) будет где-то между 0 и 150 месяцами, что также подтверждается коробчатой диаграммой;
# + Минимальный опыт работы — 0 месяцев (встречаются резюме без опыта работы), а максимальный — 1188 месяцев (99 лет);
#
# + Значения опыта работы выше 300 месяцев (25 лет) можно рассматривать как аномалии (выбросы). Эти значения находятся за пределами рисок на коробчатой диаграмме;
#
# + Большинство соискателей имеют опыт работы в диапазоне от 50 до 150 месяцев (от 0 месяцев до 12,5 лет);
#
# + Выбросы с очень большим опытом работы требуют дополнительного анализа, чтобы понять, что это за специалисты и как их опыт соотносится с требованиями к вакансиям.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построение гистограммы и коробчатой диаграммы для "ЗП (руб)"
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Гистограмма
sns.histplot(data=df, x='ЗП (руб)', bins=100, ax=axes[0])  # Увеличиваем количество bins
axes[0].set_title('Распределение ЗП (руб)')
axes[0].set_xlabel('ЗП (руб)')
axes[0].set_ylabel('Частота')

# Коробчатая диаграмма
sns.boxplot(data=df, x='ЗП (руб)', ax=axes[1])
axes[1].set_title('Коробчатая диаграмма ЗП (руб)')
axes[1].set_xlabel('ЗП (руб)')

plt.tight_layout()
plt.show()

# Описание распределения
mode_salary = df['ЗП (руб)'].mode()[0]
min_salary = df['ЗП (руб)'].min()
max_salary = df['ЗП (руб)'].max()
most_common_salary_range = "30000-100000"  # Примерный интервал по визуальному анализу

#  Определение аномалий: используем IQR, как обычно
Q1 = df['ЗП (руб)'].quantile(0.25)
Q3 = df['ЗП (руб)'].quantile(0.75)
IQR = Q3 - Q1
anomalies = df[(df['ЗП (руб)'] < (Q1 - 1.5 * IQR)) | (df['ЗП (руб)'] > (Q3 + 1.5 * IQR))]['ЗП (руб)'].unique().tolist()

print(f"Мода распределения заработной платы: {mode_salary}")
print(f"Минимальная заработная плата: {min_salary}")
print(f"Максимальная заработная плата: {max_salary}")
print(f"Примерный интервал большинства соискателей: {most_common_salary_range}")
print(f"Аномалии (выбросы): {anomalies}")

#####################################

# Подсчет соискателей с ЗП выше 1 миллиона рублей
salary_above_1m = df[df['ЗП (руб)'] > 1000000].shape[0]

# Выводим результат
print(f"Количество соискателей, требующих зарплату выше 1 миллиона рублей: {salary_above_1m}")
# Out:
# Мода распределения заработной платы: 50000.0
# Минимальная заработная плата: 1.0
# Максимальная заработная плата: 24304876.0
# Примерный интервал большинства соискателей: 30000-100000
# ...

# %% [markdown]
# ### Выводы:
#
# + Распределение желаемая заработная плата, отображенная на гистограмме и коробчатой диаграмме, имеет правостороннюю асимметрию;
#
# + Наиболее часто встречающееся желаемая заработная плата (мода) составляет 50000 рублей в месяц;
#
# + Минимальная желаемая заработная плата составляет 1 рубль, что скорее всего является ошибкой, либо неправильно указанным значением;
#
# + Максимальное желаемая заработная плата составляет 24304876.0 рублей, что скорее всего является ошибкой, либо неправильно указанным значением;
#
# + Значения желаемой заработной платы выше 185 тысяч рублей месяцев можно рассматривать как аномалии (выбросы). Эти значения находятся за пределами рисок на коробчатой диаграмме;
#
# + Большинство соискателей хотят заработную плату в районе 30000-100000 рублей в месяц;
#
# + Выбросы с очень низкой и с очень большой зарплатой требуют дополнительного анализа, чтобы понять, что это за специалисты и как их опыт соотносится с требованиями к вакансиям.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# Фильтруем данные: ЗП меньше 1 миллиона
df_filtered = df[df['ЗП (руб)'] < 1000000].copy()  # Создаем копию, чтобы избежать SettingWithCopyWarning

# Группируем и расчитываем медианную ЗП
median_salary_by_education = df_filtered.groupby('Образование')['ЗП (руб)'].median().sort_values(ascending=False)

# Строим столбчатую диаграмму
plt.figure(figsize=(10, 6))
sns.barplot(x=median_salary_by_education.index, y=median_salary_by_education.values)
plt.title('Медианная желаемая заработная плата по уровню образования (до 1 млн руб)')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная ЗП (руб)')
plt.tight_layout()
plt.show()

# Выводы по диаграмме
education_max_salary = median_salary_by_education.index[0]
education_min_salary = median_salary_by_education.index[-1]

print(f"Наибольшая медианная желаемая заработная плата наблюдается для уровня образования: {education_max_salary}")
print(f"Наименьшая медианная желаемая заработная плата наблюдается для уровня образования: {education_min_salary}")
# Out:
# Наибольшая медианная желаемая заработная плата наблюдается для уровня образования: высшее
# Наименьшая медианная желаемая заработная плата наблюдается для уровня образования: среднее специальное

# %% [markdown]
# ### Выводы:
#
# + На графике видно, что наибольшая медианная желаемая заработная плата наблюдается для соискателей с высшим образованием.
#
# + Наименьшая медианная желаемая заработная плата наблюдается для соискателей со средним образованием.
#
# + Признак уровня образования важен при прогнозировании заработной платы, так как существует явная зависимость между уровнем образования и медианной желаемой заработной платой.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Построение boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Город', y='ЗП (руб)', data=df_filtered)
plt.title('Распределение желаемой заработной платы по городам (до 1 млн руб)')
plt.xlabel('Город')
plt.ylabel('ЗП (руб)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Анализ медианных уровней и размаха
median_salary_by_city = df_filtered.groupby('Город')['ЗП (руб)'].median().sort_values(ascending=False)
salary_range_by_city = df_filtered.groupby('Город')['ЗП (руб)'].agg(lambda x: x.max() - x.min()).sort_values(ascending=False)

print("Медианные уровни желаемой заработной платы по городам:")
print(median_salary_by_city)

print("\nРазмах желаемой заработной платы по городам (максимум - минимум):")
print(salary_range_by_city)

######################

# Находим максимальную зарплату
max_salary = df['ЗП (руб)'].max()

# Находим город(а) с максимальной зарплатой
city_with_max_salary = df[df['ЗП (руб)'] == max_salary]['Город'].unique()

print(f"Город(а) с наибольшей желаемой заработной платой: {', '.join(city_with_max_salary)}")
# Out:
# Медианные уровни желаемой заработной платы по городам:
# Город
# Москва              85000.0
# Санкт-Петербург     60000.0
# город миллионник    40000.0
# другие              40000.0
# Name: ЗП (руб), dtype: float64
#
# Размах желаемой заработной платы по городам (максимум - минимум):
# Город
# другие              923982.0
# Москва              899999.0
# Санкт-Петербург     645170.0
# город миллионник    511680.6
# Name: ЗП (руб), dtype: float64
# Город(а) с наибольшей желаемой заработной платой: другие

# %% [markdown]
# ### Выводы:
#
# + Москва имеет самый высокий медианный уровень желаемой заработной платы, за ней следует Санкт-Петербург. Это отражает более высокие затраты на жизнь и общую экономическую ситуацию в этих городах;
#
# + 'Другие' города и 'город миллионник' имеют более низкие медианные значения, что может быть связано с меньшим уровнем экономических возможностей и более низкими зарплатами в регионах;
#
# + Размах заработной платы также наиболее высок в Москве и Санкт-Петербурге, что свидетельствует о большем разнообразии предлагаемых вакансий и уровней квалификации в этих городах;
#
# + Признак города безусловно важен при прогнозировании заработной платы, так как он отражает региональные различия в экономике, уровне жизни и спросе на рабочую силу.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# Создаем сводную таблицу для расчета медианной зарплаты
pivot_table = df.pivot_table(
    values='ЗП (руб)',
    index='Готовность к переезду',
    columns='Готовность к командировкам',
    aggfunc='median'
)

# Визуализация с помощью столбчатой диаграммы
pivot_table.plot(kind='bar', figsize=(8, 6))
plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=0)  # Чтобы метки оси x не поворачивались
plt.tight_layout()
plt.show()

###################################

# Вычисление медианной ЗП для готовых к переезду и командировкам
median_salary_ready = df[df['Готовность к переезду'] & df['Готовность к командировкам']]['ЗП (руб)'].median()

# Округление до тысяч
median_salary_ready_thousands = round(median_salary_ready / 1000)

print(f"Желаемая медианная заработная плата соискателей, готовых и к переезду, и к командировкам: {median_salary_ready_thousands} тысяч рублей")
# Out:
# Желаемая медианная заработная плата соискателей, готовых и к переезду, и к командировкам: 66 тысяч рублей

# %% [markdown]
# ### Выводы:
#
# + Разница между теми, кто не готов к переезду и теми, кто готов, составляет примерно 10000 рублей в месяц;
#
# + Разница между теми, кто не готов к командировкам и теми, кто готов, составляет примерно 8000 рублей в месяц;
#
# + Диаграмма показывает, что медианная желаемая заработная плата выше для соискателей, готовых к переезду и командировкам. Это говорит о том, что работодатели, готовы предложить более высокую зарплату тем, кто более мобилен и готов к переменам.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# Создаем сводную таблицу
pivot_table = df.pivot_table(
    values='ЗП (руб)',
    index='Возраст',
    columns='Образование',
    aggfunc='median'
)

# Строим тепловую карту
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".0f", linewidths=.5, cmap="YlGnBu")
plt.title('Тепловая карта медианной заработной платы в зависимости от возраста и образования')
plt.xlabel('Образование')
plt.ylabel('Возраст')
plt.show()

# %% [markdown]
# ### Выводы:
#
# + Данная тепловая карта очень сильно коррелирует с диаграммой зависимости желаемой заработной платы от образования соискателя;
#
# + Основываясь на тепловой карте, можно заметить, что наиболее быстрый карьерный рост (интенсивный рост заработной платы с возрастом) наблюдается для категории образования 'высшее';
#
# + Это выражается в наиболее заметном изменении цвета (увеличении значений) с увеличением возраста для данной категории.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# Переводим опыт работы из месяцев в годы
df['Опыт работы (год)'] = df['Опыт работы (месяц)'] / 12

# Создаем диаграмму рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(df['Возраст'], df['Опыт работы (год)'], alpha=0.5)

# Добавляем прямую
x = np.linspace(0, 100, 100)
plt.plot(x, x, color='red')

plt.xlabel('Возраст')
plt.ylabel('Опыт работы (год)')
plt.title('Зависимость опыта работы от возраста')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.show()

############################

# Фильтруем данные для точек выше прямой (строго больше)
anomalies = df[df['Опыт работы (год)'] > df['Возраст']]

# Выводим количество таких точек
print(f"Количество точек, лежащих строго выше прямой: {len(anomalies)}")
# Out:
# Количество точек, лежащих строго выше прямой: 7

# %% [markdown]
# ### Выводы:
#
# + Наблюдается положительная корреляция между возрастом и опытом работы, что является ожидаемым результатом;
#
# + Наблюдается положительная корреляция между возрастом и опытом работы, что является ожидаемым результатом;
#
# + Несколько точек расположены строго выше красной линии. Это означает, что у этих соискателей опыт работы (в годах) превышает их возраст, что невозможно. Причиной такого может быть ошибка ввода данных;
#
# + На диаграмме можно увидеть, что максимальный возраст соискателей составляет около 70-80 лет;
#
# + Также видно, что существует некоторое количество соискателей с небольшим опытом работы в более старшем возрасте, что может указывать на смену профессии или перерыв в карьере.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# График 1: Распределение количества вакансий по городам (столбчатая диаграмма)
city_counts = df['Город'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=city_counts.index, y=city_counts.values)
plt.title('Распределение количества резюме по городам')
plt.xlabel('Город')
plt.ylabel('Количество резюме')
plt.xticks(rotation=45, ha='right')
plt.show()

# График 2: Влияние образования на готовность к командировкам (столбчатая диаграмма)
plt.figure(figsize=(10, 6))
sns.countplot(x='Образование', hue='Готовность к командировкам', data=df)
plt.title('Влияние образования на готовность к командировкам')
plt.xlabel('Уровень образования')
plt.ylabel('Количество соискателей')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Выводы:
#
# #### График 1: Распределение количества резюме по городам
#
# + Москва и Санкт-Петербург - значительно большее количество резюме, чем в других категориях городов;
#
# + Города-миллионники - количество резюме больше, чем в категории "другие" города, но значительно меньше, чем в Москве и Санкт-Петербурге;
#
# + Другие города - наименьшее количество резюме;
#
# + Рынок труда в Москве и Санкт-Петербурге наиболее активен, что отражает их экономическое значение.
#
#
# #### График 2: Влияние образования на готовность к командировкам
#
# + Высшее образование - наибольшее количество соискателей с высшим образованием готовы к командировкам;
#
# + Среднее образование - большинство соискателей со средним образованием не готовы к командировкам;
#
# + Неоконченное высшее и среднее специальное - промежуточные значения;
#
# + Уровень образования влияет на готовность к командировкам. Соискатели с высшим образованием чаще готовы к командировкам, что может быть связано с особенностями работы и карьерными возможностями.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# Находим полные дубликаты
duplicates = df[df.duplicated()]

# Выводим количество дубликатов
print(f"Количество полных дубликатов: {len(duplicates)}")

# Удаляем дубликаты
df = df.drop_duplicates()
# Out:
# Количество полных дубликатов: 161

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Выводим информацию о пропусках
print(df.isnull().sum())

# Выводим количество пропусков в столбце "Опыт работы (месяц)"
print(f"\nКоличество пропусков в столбце 'Опыт работы (месяц)': {df['Опыт работы (месяц)'].isnull().sum()}")
# Out:
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# полная занятость                     0
# частичная занятость                  0
# проектная работа                     0
# волонтерство                         0
# стажировка                           0
# полный день                          0
# сменный график                       0
# гибкий график                        0
# удалённая работа                     0
# вахтовый метод                       0
# ЗП (руб)                             0
# Опыт работы (год)                  168
# dtype: int64
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаляем строки с пропусками в столбцах 'Последнее/нынешнее место работы' и 'Последняя/нынешняя должность'
df = df.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'], axis=0)

# Заполняем пропуски в столбце 'Опыт работы (месяц)' медианным значением
experience_median = df['Опыт работы (месяц)'].median()
df['Опыт работы (месяц)'] = df['Опыт работы (месяц)'].fillna(experience_median)

# Вычисляем результирующее среднее значение в столбце 'Опыт работы (месяц)'
result_mean = df['Опыт работы (месяц)'].mean()

# Округляем до целых
result_mean_rounded = round(result_mean)

print(f"Результирующее среднее значение в столбце 'Опыт работы (месяц)' после заполнения пропусков: {result_mean_rounded}")
# Out:
# Результирующее среднее значение в столбце 'Опыт работы (месяц)' после заполнения пропусков: 114

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Определяем количество выбросов
outliers = df[(df['ЗП (руб)'] > 1000000) | (df['ЗП (руб)'] < 1000)]
num_outliers = outliers.shape[0]

# Выводим количество выбросов
print(f"Количество выбросов: {num_outliers}")

# Удаляем выбросы
df = df[(df['ЗП (руб)'] <= 1000000) & (df['ЗП (руб)'] >= 1000)]
# Out:
# Количество выбросов: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Находим выбросы: опыт работы (в годах) больше возраста
outliers_experience = df[df['Опыт работы (год)'] > df['Возраст']]
num_outliers_experience = outliers_experience.shape[0]

# Удаляем выбросы
df = df[df['Опыт работы (год)'] <= df['Возраст']]

# Выводим количество выбросов
print(f"Количество выбросов: {num_outliers_experience}")
# Out:
# Количество выбросов: 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# Логарифмическое преобразование возраста
df['log_Возраст'] = np.log(df['Возраст'])

# Строим распределение в логарифмическом масштабе
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
histplot = sns.histplot(df['log_Возраст'], ax=ax, kde=True) #kde=True отображает кривую плотности

# Добавляем линии среднего и границ интервала 3 сигм
histplot.axvline(df['log_Возраст'].mean(), color='k', lw=2)
histplot.axvline(df['log_Возраст'].mean() + 3 * df['log_Возраст'].std(), color='k', lw=2, linestyle='--')
histplot.axvline(df['log_Возраст'].mean() - 3 * df['log_Возраст'].std(), color='k', lw=2, linestyle='--')
plt.title('Распределение возраста (логарифмический масштаб)')
plt.xlabel('Логарифм возраста')
plt.ylabel('Частота')
plt.show()

# Вывод об асимметрии:
print("\nРаспределение логарифма возраста асимметрично вправо.")
# То есть, хвост распределения длиннее справа, что указывает на наличие относительно небольшого количества соискателей старшего возраста.

# Находим выбросы методом z-отклонений (с учетом послабления)
mean = df['log_Возраст'].mean()
std = df['log_Возраст'].std()
lower_bound = mean - 3 * std
upper_bound = mean + 4 * std  # Послабление на 1 сигму в правую сторону
outliers = df[(df['log_Возраст'] < lower_bound) | (df['log_Возраст'] > upper_bound)]

# Выводим таблицу с выбросами
print("\nТаблица с выбросами:")
print(outliers[['Возраст']])

# Удаление выбросов
df = df[(df['log_Возраст'] >= lower_bound) & (df['log_Возраст'] <= upper_bound)]
# Out:
# Распределение логарифма возраста асимметрично вправо.
#
# Таблица с выбросами:
#        Возраст
# 31137       15
# 32950       15
# 33654      100

# %% [markdown]
# ### Выводы:
#
# + Распределение логарифма возраста асимметрично вправо;
#
# + Найдено всего 3 выброса, что является приемлимым результатам, удаление которых положительно повлияет на модель машинного обученияю
